# %%
#Step 4: Build Decision Tree Model (Scikit-Learn)
import matplotlib.pyplot as plt
import joblib
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
data = pd.DataFrame(data, columns=data.columns) # RETURN IT TO DATAFRAME TO APPLY ON IT PANDAS FEATURES AFTER IT BEEN CONVERTED TO ARRAY 
X=data.drop("target", axis=1)
Y= data["target"]

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)
## HYPERPARAMETER TUNING :
param_grid = {
    "max_depth": [3, 4, 5, 10, None],
    "min_samples_split": [2, 5, 10]
}
grid = GridSearchCV(
    DecisionTreeClassifier(random_state=42),
    param_grid,
    cv=5,
    scoring="accuracy"
)

grid.fit(X_train, y_train)

best_model = grid.best_estimator_


plt.figure(figsize=(25,10))
plot_tree(
    best_model,
    feature_names=X.columns,
    class_names=["No Disease", "Disease"],
    filled=True
)
plt.show()

joblib.dump(best_model, "heart_disease_model")
